# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
img = image.load_img('Dogo/dogo.jpeg', target_size=(200,200))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
type(img)
# Out:
# PIL.Image.Image

# %%
img = image.img_to_array(img)

# %%
img
# Out:
# array([[[253., 255., 254.],
#         [253., 255., 254.],
#         [253., 255., 254.],
#         ...,
#         [253., 254., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[253., 255., 254.],
#         [253., 255., 254.],
#         [253., 255., 254.],
#         ...,
#         [253., 254., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[253., 255., 254.],
#         [253., 255., 254.],
#         [253., 255., 254.],
#         ...,
#         [253., 254., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        ...,
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [253., 253., 253.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [254., 254., 254.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [254., 254., 254.],
#         [255., 255., 255.],
#         [255., 255., 255.]]], dtype=float32)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (200, 200, 3)

# %%
input_batch = img.reshape(1,200,200,3)

# %%
datagen = ImageDataGenerator(
        rotation_range=90,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=False,
        fill_mode='nearest')

# %%
i=0

for o in datagen.flow(input_batch,batch_size=1,save_to_dir= 'NEW_IMG'):
    i = i +1
    if i == 10:
        break

# %%
input_batch.shape
# Out:
# (1, 200, 200, 3)
